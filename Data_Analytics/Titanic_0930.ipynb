# %%
import pandas as pd
titanic=pd.read_csv("titanic.csv")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   gender    891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## Summary only for 'Object' columns i.e. Categorical columns

# %%
# Summary only for 'Object' columns i.e. Categorical columns
print(titanic.describe(include="O"))  # O - Object
# Out:
#        gender embarked deck
# count     891      889  203
# unique      2        3    7
# top      male        S    C
# freq      577      644   59

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
len(titanic)
# Out:
# 891

# %%
titanic
# Out:
#      survived  pclass  gender   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
round(titanic,0)
# Out:
#      survived  pclass  gender   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0        S  NaN
# 887         1       1  female  19.0      0      0  30.0        S    B
# 888         0       3  female   NaN      1      2  23.0        S  NaN
# 889         1       1    male  26.0      0      0  30.0        C    C
# 890         0       3    male  32.0      0      0   8.0        Q  NaN
#
# [891 rows x 9 columns]

# %%
min(titanic)
# Out:
# 'age'

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.size  # no of rows * no of columns
# Out:
# 8019

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'gender', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
titanic["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(titanic["age"])
# Out:
# pandas.core.series.Series

# %%
titanic[["age","gender"]]     # df[list of columns]
# Out:
#       age  gender
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(titanic[["age","gender"]]  )
# Out:
# pandas.core.frame.DataFrame

# %%
# using the dot notation
titanic.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic.embarked
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked, Length: 891, dtype: object

# %%
df=pd.read_csv("summer.csv",index_col="Athlete")

# %%
df.head()
# Out:
#                     Year    City  ...                       Event   Medal
# Athlete                           ...
# HAJOS, Alfred       1896  Athens  ...              100M Freestyle    Gold
# HERSCHMANN, Otto    1896  Athens  ...              100M Freestyle  Silver
# DRIVAS, Dimitrios   1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  1896  Athens  ...  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  1896  Athens  ...  100M Freestyle For Sailors  Silver
#
# [5 rows x 8 columns]

# %%
df.iloc[0] # 1st Row
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
# 2nd row
df.iloc[1]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  AUT
# Gender                   Men
# Event         100M Freestyle
# Medal                 Silver
# Name: HERSCHMANN, Otto, dtype: object

# %%
# display last row
df.iloc[-1]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: LIDBERG, Jimmy, dtype: object

# %%
# 2nd 3rd and 4th rows
df.iloc[[1,2,3]]
# Out:
#                     Year    City  ...                       Event   Medal
# Athlete                           ...
# HERSCHMANN, Otto    1896  Athens  ...              100M Freestyle  Silver
# DRIVAS, Dimitrios   1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  1896  Athens  ...  100M Freestyle For Sailors    Gold
#
# [3 rows x 8 columns]

# %%
#1st Five rows
df.iloc[:5]
# Out:
#                     Year    City  ...                       Event   Medal
# Athlete                           ...
# HAJOS, Alfred       1896  Athens  ...              100M Freestyle    Gold
# HERSCHMANN, Otto    1896  Athens  ...              100M Freestyle  Silver
# DRIVAS, Dimitrios   1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  1896  Athens  ...  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  1896  Athens  ...  100M Freestyle For Sailors  Silver
#
# [5 rows x 8 columns]

# %%
#last 5 rows
df.iloc[-5:]
# Out:
#                            Year    City      Sport  ... Gender     Event   Medal
# Athlete                                             ...
# JANIKOWSKI, Damian         2012  London  Wrestling  ...    Men  Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  ...    Men  Wg 96 KG    Gold
# TOTROV, Rustam             2012  London  Wrestling  ...    Men  Wg 96 KG  Silver
# ALEKSANYAN, Artur          2012  London  Wrestling  ...    Men  Wg 96 KG  Bronze
# LIDBERG, Jimmy             2012  London  Wrestling  ...    Men  Wg 96 KG  Bronze
#
# [5 rows x 8 columns]

# %%
# select all rows
df.iloc[:]
# Out:
#                            Year    City  ...                       Event   Medal
# Athlete                                  ...
# HAJOS, Alfred              1896  Athens  ...              100M Freestyle    Gold
# HERSCHMANN, Otto           1896  Athens  ...              100M Freestyle  Silver
# DRIVAS, Dimitrios          1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis         1896  Athens  ...  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon         1896  Athens  ...  100M Freestyle For Sailors  Silver
# ...                         ...     ...  ...                         ...     ...
# JANIKOWSKI, Damian         2012  London  ...                    Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza  2012  London  ...                    Wg 96 KG    Gold
# TOTROV, Rustam             2012  London  ...                    Wg 96 KG  Silver
# ALEKSANYAN, Artur          2012  London  ...                    Wg 96 KG  Bronze
# ...

# %%
#1st row and 1st 3 columns
df.iloc[0,:3]
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: HAJOS, Alfred, dtype: object

# %%
# 1st row and selected column
df.iloc[0,[0,2,5,7]]
# Out:
# Year          1896
# Sport     Aquatics
# Gender         Men
# Medal         Gold
# Name: HAJOS, Alfred, dtype: object

# %%
# selected rows and columns
df.iloc[34:39,[0,2,5,7]]
# Out:
#                       Year      Sport Gender   Medal
# Athlete
# GARRETT, Robert       1896  Athletics    Men  Silver
# KELLNER, Gyula        1896  Athletics    Men  Bronze
# LOUIS, Spyridon       1896  Athletics    Men    Gold
# VASILAKOS, Kharilaos  1896  Athletics    Men  Silver
# DAMASKOS, Evangelos   1896  Athletics    Men  Bronze

# %%
# Is the fourth column country? (T/F)
df.iloc[:,4].equals(df.Country)
# Out:
# True

# %%
# print athlete name and country
df['Country']
# Out:
# Athlete
# HAJOS, Alfred                HUN
# HERSCHMANN, Otto             AUT
# DRIVAS, Dimitrios            GRE
# MALOKINIS, Ioannis           GRE
# CHASAPIS, Spiridon           GRE
#                             ...
# JANIKOWSKI, Damian           POL
# REZAEI, Ghasem Gholamreza    IRI
# TOTROV, Rustam               RUS
# ALEKSANYAN, Artur            ARM
# LIDBERG, Jimmy               SWE
# Name: Country, Length: 31165, dtype: object

# %% [markdown]
# # Mask

# %%
mask1=titanic.gender=="male"    # create filter/mask
mask1
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: gender, Length: 891, dtype: bool

# %%
titanic_male=titanic.loc[mask1]
titanic_male
# Out:
#      survived  pclass gender   age  sibsp  parch     fare embarked deck
# 0           0       3   male  22.0      1      0   7.2500        S  NaN
# 4           0       3   male  35.0      0      0   8.0500        S  NaN
# 5           0       3   male   NaN      0      0   8.4583        Q  NaN
# 6           0       1   male  54.0      0      0  51.8625        S    E
# 7           0       3   male   2.0      3      1  21.0750        S  NaN
# ..        ...     ...    ...   ...    ...    ...      ...      ...  ...
# 883         0       2   male  28.0      0      0  10.5000        S  NaN
# 884         0       3   male  25.0      0      0   7.0500        S  NaN
# 886         0       2   male  27.0      0      0  13.0000        S  NaN
# 889         1       1   male  26.0      0      0  30.0000        C    C
# 890         0       3   male  32.0      0      0   7.7500        Q  NaN
#
# [577 rows x 9 columns]

# %%
titanic.gender=="male"  # same as mask1
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: gender, Length: 891, dtype: bool

# %%
titanic[titanic.gender=="male"]["fare"]
# Out:
# 0       7.2500
# 4       8.0500
# 5       8.4583
# 6      51.8625
# 7      21.0750
#         ...
# 883    10.5000
# 884     7.0500
# 886    13.0000
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 577, dtype: float64

# %%
titanic.loc[titanic.gender=="male", "fare"]  # Same as above
# Out:
# 0       7.2500
# 4       8.0500
# 5       8.4583
# 6      51.8625
# 7      21.0750
#         ...
# 883    10.5000
# 884     7.0500
# 886    13.0000
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 577, dtype: float64

# %%
titanic.loc[mask1,"fare"]  # Same as above but using Mask
# Out:
# 0       7.2500
# 4       8.0500
# 5       8.4583
# 6      51.8625
# 7      21.0750
#         ...
# 883    10.5000
# 884     7.0500
# 886    13.0000
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 577, dtype: float64

# %%
titanic_male=titanic.loc[mask1]
titanic_male
# Out:
#      survived  pclass gender   age  sibsp  parch     fare embarked deck
# 0           0       3   male  22.0      1      0   7.2500        S  NaN
# 4           0       3   male  35.0      0      0   8.0500        S  NaN
# 5           0       3   male   NaN      0      0   8.4583        Q  NaN
# 6           0       1   male  54.0      0      0  51.8625        S    E
# 7           0       3   male   2.0      3      1  21.0750        S  NaN
# ..        ...     ...    ...   ...    ...    ...      ...      ...  ...
# 883         0       2   male  28.0      0      0  10.5000        S  NaN
# 884         0       3   male  25.0      0      0   7.0500        S  NaN
# 886         0       2   male  27.0      0      0  13.0000        S  NaN
# 889         1       1   male  26.0      0      0  30.0000        C    C
# 890         0       3   male  32.0      0      0   7.7500        Q  NaN
#
# [577 rows x 9 columns]

# %%
titanic_male.head()
# Out:
#    survived  pclass gender   age  sibsp  parch     fare embarked deck
# 0         0       3   male  22.0      1      0   7.2500        S  NaN
# 4         0       3   male  35.0      0      0   8.0500        S  NaN
# 5         0       3   male   NaN      0      0   8.4583        Q  NaN
# 6         0       1   male  54.0      0      0  51.8625        S    E
# 7         0       3   male   2.0      3      1  21.0750        S  NaN

# %%
print(1912 - titanic.age)
# Out:
# 0      1890.0
# 1      1874.0
# 2      1886.0
# 3      1877.0
# 4      1877.0
#         ...
# 886    1885.0
# 887    1893.0
# 888       NaN
# 889    1886.0
# 890    1880.0
# Name: age, Length: 891, dtype: float64

# %%
titanic["YoB"]=1912 - titanic.age
titanic.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked deck     YoB
# 0         0       3    male  22.0      1      0   7.2500        S  NaN  1890.0
# 1         1       1  female  38.0      1      0  71.2833        C    C  1874.0
# 2         1       3  female  26.0      0      0   7.9250        S  NaN  1886.0
# 3         1       1  female  35.0      1      0  53.1000        S    C  1877.0
# 4         0       3    male  35.0      0      0   8.0500        S  NaN  1877.0

# %%
titanic.sibsp+titanic.parch
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Length: 891, dtype: int64

# %%
titanic["relatives"]=titanic.sibsp+titanic.parch
titanic.head()
# Out:
#    survived  pclass  gender   age  ...  embarked  deck     YoB relatives
# 0         0       3    male  22.0  ...         S   NaN  1890.0         1
# 1         1       1  female  38.0  ...         C     C  1874.0         1
# 2         1       3  female  26.0  ...         S   NaN  1886.0         0
# 3         1       1  female  35.0  ...         S     C  1877.0         1
# 4         0       3    male  35.0  ...         S   NaN  1877.0         0
#
# [5 rows x 11 columns]

# %%
titanic.drop(columns=["sibsp","parch"],inplace=True)
titanic.head()
# Out:
#    survived  pclass  gender   age     fare embarked deck     YoB  relatives
# 0         0       3    male  22.0   7.2500        S  NaN  1890.0          1
# 1         1       1  female  38.0  71.2833        C    C  1874.0          1
# 2         1       3  female  26.0   7.9250        S  NaN  1886.0          0
# 3         1       1  female  35.0  53.1000        S    C  1877.0          1
# 4         0       3    male  35.0   8.0500        S  NaN  1877.0          0

# %%
inflation_factor=10
titanic.fare*10
# Out:
# 0       72.500
# 1      712.833
# 2       79.250
# 3      531.000
# 4       80.500
#         ...
# 886    130.000
# 887    300.000
# 888    234.500
# 889    300.000
# 890     77.500
# Name: fare, Length: 891, dtype: float64

# %%
titanic.fare=titanic.fare*10
titanic.head()
# Out:
#    survived  pclass  gender   age     fare embarked deck     YoB  relatives
# 0         0       3    male  22.0   72.500        S  NaN  1890.0          1
# 1         1       1  female  38.0  712.833        C    C  1874.0          1
# 2         1       3  female  26.0   79.250        S  NaN  1886.0          0
# 3         1       1  female  35.0  531.000        S    C  1877.0          1
# 4         0       3    male  35.0   80.500        S  NaN  1877.0          0

# %%
cond1=titanic.gender=="female"
cond2=titanic.age<14

# %%
(cond1|cond2).head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
titanic.loc[cond1 | cond2]
# Out:
#      survived  pclass  gender   age     fare embarked deck     YoB  relatives
# 1           1       1  female  38.0  712.833        C    C  1874.0          1
# 2           1       3  female  26.0   79.250        S  NaN  1886.0          0
# 3           1       1  female  35.0  531.000        S    C  1877.0          1
# 7           0       3    male   2.0  210.750        S  NaN  1910.0          4
# 8           1       3  female  27.0  111.333        S  NaN  1885.0          2
# ..        ...     ...     ...   ...      ...      ...  ...     ...        ...
# 880         1       2  female  25.0  260.000        S  NaN  1887.0          1
# 882         0       3  female  22.0  105.167        S  NaN  1890.0          0
# 885         0       3  female  39.0  291.250        Q  NaN  1873.0          5
# 887         1       1  female  19.0  300.000        S    B  1893.0          0
# 888         0       3  female   NaN  234.500        S  NaN     NaN          3
#
# [351 rows x 9 columns]

# %%
titanic.loc[cond1 & cond2]
# Out:
#      survived  pclass  gender    age  ...  embarked deck      YoB  relatives
# 10          1       3  female   4.00  ...         S    G  1908.00          2
# 24          0       3  female   8.00  ...         S  NaN  1904.00          4
# 43          1       2  female   3.00  ...         C  NaN  1909.00          3
# 58          1       2  female   5.00  ...         S  NaN  1907.00          3
# 119         0       3  female   2.00  ...         S  NaN  1910.00          6
# 147         0       3  female   9.00  ...         S  NaN  1903.00          4
# 172         1       3  female   1.00  ...         S  NaN  1911.00          2
# 184         1       3  female   4.00  ...         S  NaN  1908.00          2
# 205         0       3  female   2.00  ...         S    G  1910.00          1
# 233         1       3  female   5.00  ...         S  NaN  1907.00          6
# 237         1       2  female   8.00  ...         S  NaN  1904.00          2
# ...

# %%
wom_or_chi=titanic.loc[cond1|cond2,["survived","pclass","gender","age"]]
wom_or_chi
# Out:
#      survived  pclass  gender   age
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 7           0       3    male   2.0
# 8           1       3  female  27.0
# ..        ...     ...     ...   ...
# 880         1       2  female  25.0
# 882         0       3  female  22.0
# 885         0       3  female  39.0
# 887         1       1  female  19.0
# 888         0       3  female   NaN
#
# [351 rows x 4 columns]

# %%
wom_or_chi.head()
# Out:
#    survived  pclass  gender   age
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 7         0       3    male   2.0
# 8         1       3  female  27.0

# %%
wom_or_chi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 351 entries, 1 to 888
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  351 non-null    int64
#  1   pclass    351 non-null    int64
#  2   gender    351 non-null    object
#  3   age       298 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 13.7+ KB

# %%
wom_or_chi.describe()
# Out:
#          survived      pclass         age
# count  351.000000  351.000000  298.000000
# mean     0.723647    2.205128   25.039161
# std      0.447832    0.847232   15.314631
# min      0.000000    1.000000    0.420000
# 25%      0.000000    1.000000   14.125000
# 50%      1.000000    2.000000   24.000000
# 75%      1.000000    3.000000   35.000000
# max      1.000000    3.000000   63.000000

# %%
wom_or_chi1=titanic.loc[cond1 & cond2,["survived","pclass","gender","age"]]
wom_or_chi1
# Out:
#      survived  pclass  gender    age
# 10          1       3  female   4.00
# 24          0       3  female   8.00
# 43          1       2  female   3.00
# 58          1       2  female   5.00
# 119         0       3  female   2.00
# 147         0       3  female   9.00
# 172         1       3  female   1.00
# 184         1       3  female   4.00
# 205         0       3  female   2.00
# 233         1       3  female   5.00
# 237         1       2  female   8.00
# 297         0       1  female   2.00
# 374         0       3  female   3.00
# 381         1       3  female   1.00
# 419         0       3  female  10.00
# 446         1       2  female  13.00
# 448         1       3  female   5.00
# 469         1       3  female   0.75
# 479         1       3  female   2.00
# 530         1       2  female   2.00
# 535         1       2  female   7.00
# 541         0       3  female   9.00
# 542         0       3  female  11.00
# 618         1       2  female   4.00
# ...

# %%
wom_or_chi1.head()
# Out:
#      survived  pclass  gender  age
# 10          1       3  female  4.0
# 24          0       3  female  8.0
# 43          1       2  female  3.0
# 58          1       2  female  5.0
# 119         0       3  female  2.0

# %%
wom_or_chi1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 10 to 852
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  34 non-null     int64
#  1   pclass    34 non-null     int64
#  2   gender    34 non-null     object
#  3   age       34 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.3+ KB

# %%
wom_or_chi1.describe()
# Out:
#         survived     pclass        age
# count  34.000000  34.000000  34.000000
# mean    0.617647   2.676471   5.279412
# std     0.493270   0.534880   3.522527
# min     0.000000   1.000000   0.750000
# 25%     0.000000   2.000000   2.000000
# 50%     1.000000   3.000000   4.500000
# 75%     1.000000   3.000000   8.000000
# max     1.000000   3.000000  13.000000

# %%
df
# Out:
#                            Year    City  ...                       Event   Medal
# Athlete                                  ...
# HAJOS, Alfred              1896  Athens  ...              100M Freestyle    Gold
# HERSCHMANN, Otto           1896  Athens  ...              100M Freestyle  Silver
# DRIVAS, Dimitrios          1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis         1896  Athens  ...  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon         1896  Athens  ...  100M Freestyle For Sailors  Silver
# ...                         ...     ...  ...                         ...     ...
# JANIKOWSKI, Damian         2012  London  ...                    Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza  2012  London  ...                    Wg 96 KG    Gold
# TOTROV, Rustam             2012  London  ...                    Wg 96 KG  Silver
# ALEKSANYAN, Artur          2012  London  ...                    Wg 96 KG  Bronze
# ...

# %%
g1=df.groupby("Country")
list(g1)  # To see record as per group convert into list
# Out:
# [('AFG',
#                     Year     City      Sport  ... Gender       Event   Medal
#   Athlete                                     ...
#   NIKPAI, Rohullah  2008  Beijing  Taekwondo  ...    Men     - 58 KG  Bronze
#   NIKPAI, Rohullah  2012   London  Taekwondo  ...    Men  58 - 68 KG  Bronze
#
#   [2 rows x 8 columns]),
#  ('AHO',
#                    Year   City    Sport  ... Gender                Event   Medal
#   Athlete                                ...
#   BOERSMA, Jan D.  1988  Seoul  Sailing  ...    Men  Board (Division Ii)  Silver
#
#   [1 rows x 8 columns]),
#  ('ALG',
#                         Year  ...   Medal
#   Athlete                     ...
#   ZAOUI, Mohamed        1984  ...  Bronze
#   MOUSSA, Mustapha      1984  ...  Bronze
#   BOULMERKA, Hassiba    1992  ...    Gold
#   SOLTANI, Hocine       1992  ...  Bronze
#   MORCELI, Nourredine   1996  ...    Gold
#   SOLTANI, Hocine       1996  ...    Gold
#   BAHARI, Mohamed       1996  ...  Bronze
# ...

# %%
g1.head()
# Out:
#                     Year    City  ...                       Event   Medal
# Athlete                           ...
# HAJOS, Alfred       1896  Athens  ...              100M Freestyle    Gold
# HERSCHMANN, Otto    1896  Athens  ...              100M Freestyle  Silver
# DRIVAS, Dimitrios   1896  Athens  ...  100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  1896  Athens  ...  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  1896  Athens  ...  100M Freestyle For Sailors  Silver
# ...                  ...     ...  ...                         ...     ...
# FENG, Tian Wei      2012  London  ...                        Team  Bronze
# LI, Jia Wei         2012  London  ...                        Team  Bronze
# WANG, Yuegu         2012  London  ...                        Team  Bronze
# OBAME, Anthony      2012  London  ...                     + 80 KG  Silver
# NIKPAI, Rohullah    2012  London  ...                  58 - 68 KG  Bronze
#
# [592 rows x 8 columns]

# %%
g2=df.groupby(by=["Country","Gender"])
list(g2)
# Out:
# [(('AFG', 'Men'),
#                     Year     City      Sport  ... Gender       Event   Medal
#   Athlete                                     ...
#   NIKPAI, Rohullah  2008  Beijing  Taekwondo  ...    Men     - 58 KG  Bronze
#   NIKPAI, Rohullah  2012   London  Taekwondo  ...    Men  58 - 68 KG  Bronze
#
#   [2 rows x 8 columns]),
#  (('AHO', 'Men'),
#                    Year   City    Sport  ... Gender                Event   Medal
#   Athlete                                ...
#   BOERSMA, Jan D.  1988  Seoul  Sailing  ...    Men  Board (Division Ii)  Silver
#
#   [1 rows x 8 columns]),
#  (('ALG', 'Men'),
#                         Year  ...   Medal
#   Athlete                     ...
#   ZAOUI, Mohamed        1984  ...  Bronze
#   MOUSSA, Mustapha      1984  ...  Bronze
#   SOLTANI, Hocine       1992  ...  Bronze
#   MORCELI, Nourredine   1996  ...    Gold
#   SOLTANI, Hocine       1996  ...    Gold
#   BAHARI, Mohamed       1996  ...  Bronze
# ...

# %%
df.groupby(by=["Country","Gender"]).sum()
# Out:
# /tmp/ipykernel_7863/1731392243.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by=["Country","Gender"]).sum()
#                   Year
# Country Gender
# AFG     Men       4020
# AHO     Men       1988
# ALG     Men      23968
#         Women     6000
# ANZ     Men      51548
# ...                ...
# YUG     Women   122976
# ZAM     Men       3980
# ZIM     Women    45724
# ZZX     Men      85508
#         Women     5700
#
# [236 rows x 1 columns]

# %%
df.groupby(by=["Country","Gender"]).count()
# Out:
#                 Year  City  Sport  Discipline  Event  Medal
# Country Gender
# AFG     Men        2     2      2           2      2      2
# AHO     Men        1     1      1           1      1      1
# ALG     Men       12    12     12          12     12     12
#         Women      3     3      3           3      3      3
# ANZ     Men       27    27     27          27     27     27
# ...              ...   ...    ...         ...    ...    ...
# YUG     Women     62    62     62          62     62     62
# ZAM     Men        2     2      2           2      2      2
# ZIM     Women     23    23     23          23     23     23
# ZZX     Men       45    45     45          45     45     45
#         Women      3     3      3           3      3      3
#
# [236 rows x 6 columns]
